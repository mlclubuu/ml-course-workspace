# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance_encoder_dataset_1k.csv')
df
# Out:
#      age  gender region income_level  have_insurance
# 0     56  Female   East         High               1
# 1     69  Female  South       Medium               0
# 2     46    Male   West       Medium               0
# 3     32  Female  North       Medium               0
# 4     60  Female   East          Low               1
# ..   ...     ...    ...          ...             ...
# 995   37    Male   East       Medium               0
# 996   41    Male  South         High               0
# 997   22    Male   East          Low               0
# 998   51  Female  North       Medium               0
# 999   23  Female   West       Medium               0
#
# [1000 rows x 5 columns]

# %%
'''
encoding part...

i. Labal Encoder
ii. Dummyes Encoder
iii. OneHotEncoder
'''
# Out:
# '\nencoding part...\n\ni. Labal Encoder\nii. Dummyes Encoder\niii. OneHotEncoder\n'

# %%
# Label Encoder
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder_result = encoder.fit_transform(df['region'])
encoder_result
# Out:
# array([0, 2, 3, 1, 0, 2, 2, 0, 0, 3, 1, 1, 0, 0, 1, 1, 1, 3, 1, 2, 1, 2,
#        1, 2, 1, 3, 1, 2, 3, 0, 2, 2, 2, 0, 3, 0, 0, 0, 2, 1, 0, 3, 1, 0,
#        1, 2, 1, 2, 0, 2, 0, 0, 3, 1, 2, 1, 3, 3, 2, 3, 2, 0, 1, 0, 1, 3,
#        0, 0, 1, 2, 1, 2, 1, 3, 0, 2, 2, 2, 0, 2, 3, 2, 3, 3, 1, 3, 1, 3,
#        2, 3, 3, 3, 0, 2, 1, 2, 1, 0, 2, 3, 0, 3, 1, 3, 3, 2, 0, 0, 1, 2,
#        2, 1, 2, 1, 1, 1, 3, 2, 3, 2, 2, 2, 2, 1, 0, 1, 0, 0, 1, 1, 0, 2,
#        1, 3, 1, 0, 3, 1, 1, 1, 2, 1, 0, 1, 2, 3, 3, 0, 2, 0, 2, 2, 1, 3,
#        2, 1, 2, 2, 3, 0, 0, 1, 2, 2, 1, 1, 0, 1, 2, 1, 1, 1, 3, 3, 3, 2,
#        1, 2, 2, 3, 1, 2, 1, 2, 0, 2, 2, 2, 2, 0, 3, 3, 0, 2, 0, 2, 1, 3,
#        1, 3, 2, 0, 0, 3, 0, 0, 1, 2, 1, 0, 2, 0, 1, 1, 0, 1, 1, 1, 3, 0,
#        2, 1, 2, 0, 0, 1, 1, 1, 0, 0, 1, 1, 1, 3, 1, 0, 0, 2, 1, 1, 0, 0,
#        0, 2, 1, 3, 0, 1, 3, 0, 0, 0, 3, 0, 1, 2, 3, 1, 2, 2, 2, 0, 3, 1,
#        1, 1, 3, 0, 1, 3, 3, 3, 3, 1, 0, 2, 3, 0, 0, 0, 1, 2, 3, 3, 1, 1,
# ...

# %%
encoded_result = pd.get_dummies(df['region'], drop_first=True)
encoded_result
# Out:
#      North  South   West
# 0    False  False  False
# 1    False   True  False
# 2    False  False   True
# 3     True  False  False
# 4    False  False  False
# ..     ...    ...    ...
# 995  False  False  False
# 996  False   True  False
# 997  False  False  False
# 998   True  False  False
# 999  False  False   True
#
# [1000 rows x 3 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded_results = encoder.fit_transform(df[['region']])
encoded_results = pd.DataFrame(encoded_result)

# %%
encoded_result
# Out:
#      North  South   West
# 0    False  False  False
# 1    False   True  False
# 2    False  False   True
# 3     True  False  False
# 4    False  False  False
# ..     ...    ...    ...
# 995  False  False  False
# 996  False   True  False
# 997  False  False  False
# 998   True  False  False
# 999  False  False   True
#
# [1000 rows x 3 columns]

# %%
df = pd.read_csv('insurance.csv')
df
# Out:
#     age  have_insurance
# 0    56               1
# 1    69               1
# 2    46               0
# 3    32               1
# 4    60               1
# ..  ...             ...
# 94   21               0
# 95   71               1
# 96   46               1
# 97   80               1
# 98   35               0
#
# [99 rows x 2 columns]

# %%
plt.Figure(figsize=(8,4))
plt.scatter(df['age'], df['have_insurance'])
plt.show()

# %%
X = df[['age']]
y = df['have_insurance']

print(type(X))
print(type(y))
# Out:
# <class 'pandas.DataFrame'>
# <class 'pandas.Series'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
X_train = X_train.values.reshape(-1,1)
X_test = X_test.values.reshape(-1,1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[30], [40], [50], [60], [70]])
# Out:
# array([0, 0, 1, 1, 1])

# %%
model.score(X_test, y_test)
# Out:
# 0.7333333333333333

# %%
import joblib
joblib.dump(model, 'logistic_regression_model.pkl')
# Out:
# ['logistic_regression_model.pkl']

# %%
model = joblib.load('logistic_regression_model.pkl')
model.predict([[30], [40], [50], [60], [70]])
# Out:
# C:\Users\mahfujur\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0, 0, 1, 1, 1])

# %%
# Concatenate side by side (columns)
result = pd.concat([df1, df2], axis=1)

# Concatenate vertically (rows)
result = pd.concat([df1, df2], axis=0)
